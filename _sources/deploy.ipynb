# %% [markdown]
# # Tugas Deploy Aplikasi

# %% [markdown]
# NAMA : Yudha Nuur Cahyo
#
# NIM : 220411100052
#
# MATA KULIAH : Pencarian dan Penambangan Web - A

# %% [markdown]
# ## Aplikasi Klasifikasi Berita

# %% [markdown]
# Aplikasi ini memungkinkan pengguna untuk mengklasifikasikan teks berita ke dalam kategori "Nasional" atau "Bisnis" menggunakan model klasifikasi berbasis regresi logistik.

# %% [markdown]
# https://huggingface.co/spaces/yudhanuurcahyo/test-py

# %% [markdown]
# ## Visualisasi Sentimen Berita dengan Jaringan Graf

# %% [markdown]
# Aplikasi ini memungkinkan pengguna untuk memproses teks berita dan menganalisis sentimen dari setiap kalimat menggunakan model klasifikasi sentimen berbasis regresi logistik.

# %% [markdown]
# https://huggingface.co/spaces/yudhanuurcahyo/graph-app

# %% [markdown]
# ## Aplikasi Klasifikasi Berita (SVD)

# %% [markdown]
# Aplikasi ini mengklasifikasikan berita ke dalam kategori Bisnis dan Nasional menggunakan Logistic Regression dan Reduksi Dimensi dengan Singular Value Decomposition (SVD).

# %% [markdown]
# https://huggingface.co/spaces/yudhanuurcahyo/Klasifikasi-Berita

# %% [markdown]
# ## Aplikasi Klasifikasi Berita (SVD & FCM)

# %% [markdown]
# Aplikasi ini mengklasifikasikan berita ke dalam kategori Otomotif dan Keuangan menggunakan pipeline SVD dan FCM.

# %% [markdown]
# https://huggingface.co/spaces/yudhanuurcahyo/fuzzy_cmeans
